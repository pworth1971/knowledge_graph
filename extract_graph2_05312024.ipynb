# %% [markdown]
# ## Setup

# %%
#pip install langchain langchain-community

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
#data_dir = "cureus"
data_dir = 'tr'
inputdirectory = Path(f"./data_input/{data_dir}")

## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %%
inputdirectory
# Out:
# PosixPath('data_input/tr')

# %%
outputdirectory
# Out:
# PosixPath('data_output/tr')

# %% [markdown]
# ## Load Documents

# %%
#pip install unstructured

# %%
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.39s/it]
# Number of chunks =  68
# system as a whole informs local events as it were.ld as an expression of divine consciousness where the of um Theory, we have been exposed to a variety of intellectual

# %%
documents
# Out:
# [Document(page_content='Metaphysics of Awareness\r\rIn many respects, one can consider the age that we live in, the Quantum Era, as one of intense intellectual \rcrisis and turmoil, very much analogous to the crisis that the intellectuals faced during the Enlightenment Era \rafter the world had almost literally been turned upside down. We see clear indications of this crisis, \rmanifestations as it were, on the world stage with \r\ri.\tglobal warming: a threat on a scale that we as a global community have ever faced before and has the \rpotential for devastating consequences, some of which are already starting to see. Changing climate \rleading to shortages of and lack of food and water, large scale people unrest and movement leading to \rfurther political instability. ii. nuclear proliferation: an increasing number of nation states have access to, and are actively working on, \rnuclear weaponry, \riii. rise of radical extremism: aka Terrorism, which primarily is looked at through an Islamic lens but runs \rdeeper than that and is not necessarily a fundamentally religious problem much less an Islamic one,\riv.\n\nthe rise of nationalism: aka populism that is sweeping through Western democracies like a cancer almost, \rBrexit and the rise of Trumpism in the United States as perhaps the most glaring examples, and\rv.\tincreasing wealth inequality: leading to general unrest and broad class inequality even within wealthy \rnations, also starting to take root between nations as well, \r\rAll of these socio-political trends, and particularly those that are leading to socio-political instability and \rchange, grouped with the threat of Terrorism and nuclear proliferation, together significantly increase the \rprobability of not just instability, but conflict and destruction at a scale that we have not encountered in the \rhistory of mankind. Furthermore, many of these threats, or trends, are a direct result of, or at least are \rpartially caused by, ideological differences and/or deficiencies. This is the case in particular with respect to \rthe rise of nationalism, increasing income inequality, as well as Terrorism, both underlying socio-political \rtrends that, when paired with Global Warming and the resulting shift in access to resources, put mankind in a \rprecarious position indeed.\n\nIf we take them all together then, given their global scope and reach, and given the ideological basis for at \rleast a core group of them, it is not too much of a stretch to argue that at least some degree (and we would \rargue to a large degree), these trends are a function of, a direct result of, the proliferation of Western \rideology throughout the world which rests on not so much democracy and freedom (although this is what \rmany of our leaders in the West would have us believe), but more so on capitalism and materialism, precisely \rthe hot buttons for the radical extremists, which in turn drive radical (religious) extremism to a large extent. Therefore, it is a logical and rational deduction to conclude that these trends, these problems and challenges \rthat characterize the modern era within which we live, while manifesting of course on the material or \rphysical plane, if not addressed ideologically, are fundamentally unsolvable - each of them potentially having \rdevastating effects to the global community and all of them together representing arguably the greatest \rthreat mankind has ever faced, certainly modern man.\n\nFrom a pure intellectual perspective, from a metaphysical perspective, we see analogs for these ideological \rchallenges in the domain of Physics, crystalizing in the search for a so-called Unified Field Theory, a quest first \routlined by Einstein after the advancements of Quantum Theory - a theoretical framework which although \rextraordinarily powerful leading to all sorts of amazing and revolutionary scientific advancements, \rnonetheless forces us to look very hard and close at the principles of causal determinis ...

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
#pip install yachalk

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (68, 3)
#                                                 text                source  \
# 0  Metaphysics of Awareness\r\rIn many respects, ...  data_input/tr/tr.txt
# 1  the rise of nationalism: aka populism that is ...  data_input/tr/tr.txt
# 2  If we take them all together then, given their...  data_input/tr/tr.txt
# 3  From a pure intellectual perspective, from a m...  data_input/tr/tr.txt
# 4  We also have at the same time, due in no small...  data_input/tr/tr.txt
#
#                            chunk_id
# 0  ce1d386a3e194fb3a647e9b042b48221
# 1  d53bb76260354f97b2371261f9d56b0f
# 2  f78ee4b81d7d447e95185a4c3fdf2432
# 3  568f10f17e7b40edb122de1200e7f24e
# 4  b998d992c22c43d9b920a21b5424e4aa

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# [
#    {
#        "node_1": "Quantum Era",
#        "node_2": "Intense intellectual crisis and turmoil",
#        "edge": "The age we live in, characterized by advancements in quantum physics, has led to a complex understanding of the world that has left many intellectuals grappling with new concepts and ideas. This intellectual upheaval can be compared to the Enlightenment Era when society was trying to come to terms with the consequences of scientific discoveries."
#    },
#    {
#        "node_1": "Global warming",
#        "node_2": "Intense intellectual crisis and turmoil",
#        "edge": "The threat of global warming, on a scale unprecedented in human history, has posed a significant challenge for the global community. This issue has led to intense debates among scientists, policymakers, and other stakeholders as they try to understand its implications and find solutions."
#    },
#    {
#        "node_1": "Global warming",
#        "node_2": "Shortages of and lack of food and water",
#        "edge": "Rising global temperatures are leading to severe droughts, melting glaciers, and rising sea levels. These factors have the potential to cause shortages of and lack of food and water, especially in vulnerable regions."
#    },
#    {
#        "node_1": "Global warming",
#        "node_2": "Large scale people unrest and movement leading to further political instability",
#        "edge": "The impact of global warming is not limited to environmental issues. It has the potential to trigger large-scale social, economic, and political upheavals, as communities struggle to adapt to changing realities."
#    },
#    {
#        "node_1": "Nuclear proliferation",
#        "node_2": "Intense intellectual crisis and turmoal",
#        "edge": "The increasing number of nation-states with access to nuclear weaponry is a cause for concern. This issue has led to intense debates among policymakers, scientists, and other stakeholders as they try to understand its implications and find solutions."
#    },
#    {
#        "node_1": "Rise of radical extremism",
#        "node_2": "Intense intellectual crisis and turmoal",
#        "edge": "The phenomenon of radical extremism, often associated with Islam, is not necessarily a religious issue. It runs deeper than that and is a complex socio-political challenge that requires a nuanced understanding and response."
# ]
#
# ERROR ### Here is the buggy response:  [
#    {
#        "node_1": "Quantum Era",
#        "node_2": "Intense intellectual crisis and turmoil",
#        "edge": "The age we live in, characterized by advancements in quantum physics, has led to a complex understanding of the world that has left many intellectuals grappling with new concepts and ideas. This intellectual upheaval can be compared to the Enlightenment Era when society was trying to come to terms with the consequences of scientific discoveries."
#    },
#    {
#        "node_1": "Global warming",
#        "node_2": "Intense intellectual crisis and turmoil",
#        "edge": "The threat of global warming, on a scale unprecedented in human history, has posed a significant challenge for the global community. This issue has led to intense debates among scientists, policymakers, and other stakeholders as they try to understand its implications and find solutions."
#    },
#    {
#        "node_1": "Global warming",
#        "node_2": "Shortages of and lack of food and water",
#        "edge": "Rising global temperatures are leading to severe droughts, melting glaciers, and rising sea levels. These factors have the potential to cause shortages of and lack of food and water, especially in vulnerable regions."
#    },
#    {
#        "node_1": "Global warming",
#        "node_2": "Large scale people unrest and movement leading to further political instability",
#        "edge": "The impact of global warming is not limited to environmental issues. It has the potential to trigger large-scale social, economic, and political upheavals, as communities struggle to adapt to changing realities."
#    },
#    {
#        "node_1": "Nuclear proliferation",
#        "node_2": "Intense intellectual crisis and turmoal",
#        "edge": "The increasing number of nation-states with access to nuclear weaponry is a cause for concern. This issue has led to intense debates among policymakers, scientists, and other stakeholders as they try to understand its implications and find solutions."
#    },
#    {
#        "node_1": "Rise of radical extremism",
#        "node_2": "Intense intellectual crisis and turmoal",
#        "edge": "The phenomenon of radical extremism, often associated with Islam, is not necessarily a religious issue. It runs deeper than that and is a complex socio-political challenge that requires a nuanced understanding and response."
# ]
#
#
# [
#    {
#        "node_1": "rise of nationalism",
#        "node_2": "Brexit",
#        "edge": "Brexit is an example of the rise of nationalism, as it represents a popular vote for Britain to leave the European Union, driven by nationalistic sentiments."
#    },
#    {
#        "node_1": "rise of nationalism",
#        "node_2": "Trumpism",
#        "edge": "Trumpism refers to the nationalistic ideology and political approach espoused by U.S. President Donald Trump, which has gained significant popularity in recent times."
#    },
#    {
#        "node_1": "rise of nationalism",
#        "node_2": "populism",
#        "edge": "Nationalism is a form of populism that emphasizes the interests and identity of a particular nation or ethnic group over other groups, often to the detriment of international cooperation and understanding."
#    },
#    {
#        "node_1": "increasing wealth inequality",
#        "node_2": "general unrest",
#        "edge": "Wealth inequality has been linked to social unrest, as those who feel left behind or oppressed by the wealthy elite may take action to challenge their position."
#    },
#    {
#        "node_1": "increasing wealth inequality",
#        "node_2": "broad class inequality",
#        "edge": "Wealth inequality is a major contributor to class inequality, as those with more resources are better equipped to access opportunities and power."
#    },
#    {
#        "node_1": "ideological differences",
#        "node_2": "nationalism",
#        "edge": "Nationalism often arises from ideological differences, as people may feel a strong sense of national identity or pride that separates them from other groups."
#    },
#    {
#        "node_1": "ideological differences",
#        "node_2": "terrorism",
#        "edge": "Ideological differences can also lead to terrorism, as extremists may use violence as a means of achieving their political goals."
#    },
#    {
#        "node_1": "global warming",
#        "node_2": "resource access",
#        "edge": "Global warming is leading to changes in resource access and availability, as certain areas become more vulnerable to natural disasters or suffer from water scarcity."
#    },
#    {
#        "node_1": "global warming",
#        "node_2": "precarity of mankind",
#        "edge": "The combination of global warming and other trends, such as ideological differences and wealth inequality, is putting the future of humanity in a precarious position indeed."
#    }
# ][
#   {
#     "node_1": "Western ideology",
#     "node_2": "Capitalism and materialism",
#     "edge": "Precisely these hot buttons for the radical extremists drive radical (religious) extremism to a large extent."
#   },
#   {
#     "node_1": "Global scope and reach of trends",
#     "node_2": "Ideological basis for at least a core group of them",
#     "edge": "Given their global scope and reach, and given the ideological basis for at least a core group of them,"
#   },
#   {
#     "node_1": "Radical extremism",
#     "node_2": "Western ideology",
#     "edge": "While manifesting on the material or physical plane, if not addressed ideologically,"
#   },
#   {
#     "node_1": "Greatest threat mankind has ever faced",
#     "node_2": "These trends, these problems and challenges",
#     "edge": "Each of them potentially having devastating effects to the global community and all of them together representing arguably the greatest threat mankind has ever faced,"
#   },
#   {
#     "node_1": "Democracy and freedom",
#     "node_2": "Western ideology",
#     "edge": "Although this is what many of our leaders in the West would have us believe",
#   }
# ]
#
# ERROR ### Here is the buggy response:  [
#   {
#     "node_1": "Western ideology",
#     "node_2": "Capitalism and materialism",
#     "edge": "Precisely these hot buttons for the radical extremists drive radical (religious) extremism to a large extent."
#   },
#   {
#     "node_1": "Global scope and reach of trends",
#     "node_2": "Ideological basis for at least a core group of them",
#     "edge": "Given their global scope and reach, and given the ideological basis for at least a core group of them,"
#   },
#   {
#     "node_1": "Radical extremism",
#     "node_2": "Western ideology",
#     "edge": "While manifesting on the material or physical plane, if not addressed ideologically,"
#   },
#   {
#     "node_1": "Greatest threat mankind has ever faced",
#     "node_2": "These trends, these problems and challenges",
#     "edge": "Each of them potentially having devastating effects to the global community and all of them together representing arguably the greatest threat mankind has ever faced,"
#   },
#   {
#     "node_1": "Democracy and freedom",
#     "node_2": "Western ideology",
#     "edge": "Although this is what many of our leaders in the West would have us believe",
#   }
# ]
#
#
# [
#    {
#       "node_1": "intellectual perspective",
#       "node_2": "metaphysical perspective",
#       "edge": "From a pure intellectual and metaphysical perspective, we see analogs for these ideological challenges in the search for a Unified Field Theory."
#    },
#    {
#       "node_1": "Unified Field Theory",
#       "node_2": "Einstein",
#       "edge": "Einstein first outlined the quest for a Unified Field Theory after the advancements of Quantum Theory."
#    },
#    {
#       "node_1": "Quantum Theory",
#       "node_2": "Classical Mechanics",
#       "edge": "From a pure intellectual perspective, from a metaphysical perspective, we see analogs for these ideological challenges in the domain of Physics, crystalizing in the search for a so-called Unified Field Theory where Classical Mechanics and Quantum Theory both coexist."
#    },
#    {
#       "node_1": "many worlds interpretation",
#       "node_2": "Bohmian Mechanics",
#       "edge": "Since the introduction and acceptance of Quantum Theory, we have been exposed to a variety of intellectual paradigms intended to explain how these seemingly contradictory worlds, Classical Mechanics and Quantum Theory, can both be true at the same time - many worlds interpretation being one such example, or Bohmian Mechanics which has given us this notion of holomovement and implicate order."
#    },
#    {
#       "node_1": "locality",
#       "node_2": "Eastern philosophy",
#       "edge": "Furthermore, these developments in Physics have interestingly led to many proponents of Eastern philosophy to look at some of the underlying foundational precepts of Quantum Theory - locality being perhaps the most prominent of these - as consistent with their ontology, the world as an expression of divine consciousness where the system as a whole informs local events as it were."
#    },
#    {
#       "node_1": "Classical Mechanics",
#       "node_2": "Quantum Theory",
#       "edge": "From a pure intellectual perspective, from a metaphysical perspective, we see analogs for these ideological challenges in the search for a so-called Unified Field Theory where Classical Mechanics and Quantum Theory both coexist."
#    }
# ][
#    {
#        "node_1": "Eastern philosophical traditions",
#        "node_2": "Spread of Eastern philosophical traditions",
#        "edge": "Since the beginning of the 20th century, due to globalization and technological advancements, Eastern philosophical traditions have spread beyond their traditional borders in the West. This diffusion has been largely driven by materialistic factors, such as an obsession with health and well-being. However, this spread also has significant philosophical and theological implications. The Eastern worldview is now familiar to many people in the West, and the concept of an underlying, active consciousness that manifests both the mind and physical world is not entirely foreign or outrageous."
#    },
#    {
#        "node_1": "Eastern philosophical traditions",
#        "node_2": "Rejection by Scientific community",
#        "edge": "Despite the fact that the idea of an underlying, active consciousness from which both the mind and physical world manifest rests or depends upon for existence has been largely rejected by the Scientific community."
#    }
# ][
#    {
#        "node_1": "Religion",
#        "node_2": "Theological belief systems",
#        "edge": "The rational foundations of Religion, theology, has been under attack since the Scientific Revolution more or less. These forms of Eastern philosophy integrate theology and metaphysics, along with spiritual practices like meditation, to facilitate and demonstrate the underlying ontological truth of said theological belief systems."
#    }, {
#        "node_1": "Religion",
#        "node_2": "Islam",
#        "edge": "In particular, Islam is looked upon almost as barbaric in a way, as we see for example in how Islam is viewed."
#    }, {
#        "node_1": "Religion",
#        "node_2": "Terrorism",
#        "edge": "These trends have not only metaphysical and theological implications, but also moral and ethical ones as well. The problem effectively runs across a variety of intellectual lines but, like alcoholism or drug addiction or any problem for that matter, the first step to solving said problem is recognizing that there is in fact a problem."
#    }, {
#        "node_1": "Religion",
#        "node_2": "Morality and ethics",
#        "edge": "A further attack on the religious establishment while (superficially) many may not have a problem with, and many in the atheist community especially directly espouse, leads us to the very precarious position again as to the basis of, and fundamental attributes of, morality and ethics."
#    }
# ][
#    {
#        "node_1": "scale of some of these issues",
#        "node_2": "inherent complexity",
#        "edge": "require action at the individual level in order for us to at least have a fighting chance to solve them. Politics is local as they say."
#    },
#    {
#        "node_1": "individual problems we have laid out",
#        "node_2": "level of crisis that we are at given the scope of all of the problems put together",
#        "edge": "It's not clear that we as a global community have reached that conclusion yet - not just for each of the individual problems we have laid out, but even the level of crisis that we are at given the scope of all of the problems put together."
#    },
#    {
#        "node_1": "individual problems",
#        "node_2": "each of them individually and then the group of them collectively",
#        "edge": "Having said that, certainly a step in the right direction is to try and establish the proper and appropriate intellectual framework out of which the solutions to these problems - each of them individually and then the group of them collectively - at least have the potential of being solved."
#    },
#    {
#        "node_1": "nation-state and global level",
#        "node_2": "socio-political structures",
#        "edge": "need to be established that again have the appropriate intellectual paradigm or worldview such that the problems can be attacked and addressed at the nation-state and global level - a two-pronged approach as it were."
#    }
# ][
#    {
#        "node_1": "intellectual framework",
#        "node_2": "proper and appropriate intellectual framework",
#        "edge": "From the author's point of view at least, in order to establish the proper and appropriate intellectual framework we must truly recognize - from an epistemological perspective - that..."
#    }, {
#        "node_1": "supracconsciousness",
#        "node_2": "underlying ground of existence",
#        "edge": "...that the underlying ground of existence, what we have called supraconsciousness,"
#    }, {
#        "node_1": "mystical experience",
#        "node_2": "ethereal thing",
#        "edge": "...and the countless other messages from saints and prophets throughout the ages,"
#    }, {
#        "node_1": "son of a carpenter",
#        "node_2": "Jesus Christ",
#        "edge": "...some two thousand years ago, and the countless other messages from saints and prophets throughout the ages,"
#    }, {
#        "node_1": "social good",
#        "node_2": "liberal or philosophical idea",
#        "edge": "God - if he does indeed exist - needs to be placed on former, more realistic, footing such that morality and the social good in and of itself is not a 'liberal' or philosophical idea,"
#    }, {
#        "node_1": "interconnectedness",
#        "node_2": "all living beings",
#        "edge": "...but is the most practical of rational deductions that is based upon the fundamental understanding of the interconnectedness of all living beings - again not on just an intellectual or ethereal level, but on a practical and very grounded level as reflected in the 'mystical' experience as it is understood by the Eastern philosophical traditions."
#    }
# ][
#    {
#        "node_1": "dualistic world",
#        "node_2": "objectivity",
#        "edge": "in this context, the concept of a dualistic world is related to the concept of objectivity because even the very description of the problem of determining the extent to which mystical frameworks can be laid out in a pure rational model is tainted with objectivity, as it presupposes a separation between that which is perceived and the perceiver. This separation reinforces the dualistic nature of our worldview."
#    },
#    {
#        "node_1": "divine being",
#        "node_2": "God",
#        "edge": "the concept of a divine being, i.e. God, is related to the concept of God because both concepts refer to a supernatural entity that is believed to have created the universe and us."
#    },
#    {
#        "node_1": "intellectual paradigm",
#        "node_2": "context of crises",
#        "edge": "the concept of an intellectual paradigm is related to the context of crises because the need for an intellectual paradigm arises in response to the challenges and threats that are confronting us during times of crisis."
#    },
#    {
#        "node_1": "necessary condition",
#        "node_2": "successfully through the crisis of our time",
#        "edge": "the concept of a necessary condition is related to the concept of successfully passing through the crisis of our time because both concepts refer to conditions that must be met in order for us to overcome the challenges and threats we face during times of crisis."
#    }
# ]
# [
#    {
#        "node_1": "ontology",
#        "node_2": "being",
#        "edge": "Ontology is the science of being or reality."
#    },
#    {
#        "node_1": "ontology",
#        "node_2": "reality",
#        "edge": "Ontology is the science of reality."
#    },
#    {
#        "node_1": "being",
#        "node_2": "existence",
#        "edge": "Being and existence are often used interchangeably, but being may also refer to qualities or attributes beyond simple existence."
#    },
#    {
#        "node_1": "ontology",
#        "node_2": "science",
#        "edge": "Ontology is a scientific discipline that explores the nature of being and reality."
#    },
#    {
#        "node_1": "reality",
#        "node_2": "objective",
#        "edge": "Reality is often considered objective, implying a separation between the subject (observer) and object (being observed)."
#    }
# ][
#    {
#        "node_1": "Indo-European linguistic construct",
#        "node_2": "subject verb object",
#        "edge": "providing a tremendously powerful intellectual tool through which we can not only explore our reality, our world - describe it, articulate it, improve upon it, etc. - but also persist information and knowledge itself so that the sum total of knowledge is carried forward from one generation to the next with a high degree of specificity."
#    }, {
#        "node_1": "subject-object-metaphysics",
#        "node_2": "linguistic framework",
#        "edge": "embedded into not just our intellectual framework, but even our linguistic framework as well, leaving us with a classical chick and egg problem as it were. Once that linguistic invention is applied, we are left with the foregone conclusion that our worldview must be reductionist - it has to be, because that is the only way we can express anything, in any Indo-European language really, the language family that that has provided the linguistic, and effectively the intellectual, foundations of the West. Every time you try and solve it you go further down the rabbit hole as it were."
#    }
# ][
#    {
#        "node_1": "God",
#        "node_2": "creation",
#        "edge": "God is everything, God is in everything and as such is the ground of all experience and in turn is the (intellectual as well as physical and spiritual) ground of experience in and of itself - this is essentially what we find in Upanishadic philosophy as Satcitānanda and in the West is reflected perhaps most eloquently in the Neo-Platonic One. So linguistically then, we are almost forced to go back to the very foundations of theology, metaphysics really, in order to connect this very ancient notion of God as an integral aspect of his creation - God is everything, God is in everything and as such is the ground of all experience and in turn is the (intellectual as well as physical and spiritual) ground of experience in and of itself."
#    }, {
#        "node_1": "God",
#        "node_2": "experience",
#        "edge": "God is the (intellectual as well as physical and spiritual) ground of experience in and of itself."
#    }, {
#        "node_1": "Satcitānanda",
#        "node_2": "God",
#        "edge": "Essentially what we find in Upanishadic philosophy as Satcitānanda is God."
#    }, {
#        "node_1": "Neo-Platonism",
#        "node_2": "One",
#        "edge": "The Neo-Platonic One reflects perhaps most eloquently in the West what we find in Upanishadic philosophy as Satcitānanda."
#    }, {
#        "node_1": "intellectual as well as physical and spiritual ground of experience",
#        "node_2": "God",
#        "edge": "God is the (intellectual as well as physical and spiritual) ground of experience in and of itself."
#    }, {
#        "node_1": "very ancient notion of God",
#        "node_2": "creation",
#        "edge": "God as an integral aspect of his creation - God is everything, God is in everything"
#    }
# ][
#    {
#        "node_1": "philosophia",
#        "node_2": "Western thought",
#        "edge": "In these initial intellectual systems, the philosophia of the West was laid as a function of the Indo-European subject and object based linguistic constructs, effectively the foundations Western thought."
#    },
#    {
#        "node_1": "Science",
#        "node_2": "Western thought",
#        "edge": "After Philosophy as a discipline split between natural and theoretical lines, Science reflects the reductionist emphasis that we are confronted with today."
#    },
#    {
#        "node_1": "Plato",
#        "node_2": "metaphysician",
#        "edge": "Plato primarily as the perhaps the first metaphysician"
#    },
#    {
#        "node_1": "Plato",
#        "node_2": "theologian",
#        "edge": "Despite his rational bent, he still nonetheless captured in a way that ancient mystical quality that is characteristic of the Paleolithic religions throughout Eurasia which preceded him - what we refer to quite broadly as shamanism."
#    },
#    {
#        "node_1": "Plotinus",
#        "node_2": "Neo-Platonist",
#        "edge": "This mystic quality is again best captured in the Platonic philosophy of Plotinus, the quintessential Neo-Platonist"
#    },
#    {
#        "node_1": "One",
#        "node_2": "many",
#        "edge": "His doctrine of the One which manifests itself, via emanation of sorts, into the many by way of the Divine Intellect, or Nous."
#    },
#    {
#        "node_1": "Neo-Platonism",
#        "node_2": "Indian philosophy",
#        "edge": "From a mystical and theological standpoint in fact is eerily similar to its Indo-European brother on the Indian subcontinent, the philosophy we find implicit to the Upanishads which forms the basis of Vedānta."
#    }
# ]
# [
#    {
#        "node_1": "Brahman",
#        "node_2": "Brahmā",
#        "edge": "Brahman, a metaphysical abstraction in the extracted ontology, is related to Brahmā, the creator of the universe in the Vedic mythos. This relationship stems from Brahman being minus the numerological significance inherent to the Neo-Platonic One."
#    },
#    {
#        "node_1": "Nous",
#        "node_2": "Ṛta",
#        "edge": "The cosmic ordering principle of Ṛta, which comes to be understood as dharma in the later Indian philosophical tradition and Buddhism, corresponds quite elegantly to Nous, a sort of Divine Intellect that is rational and reflects a sense of order in Neo-Platonic philosophy."
#    },
#    {
#        "node_1": "Dharma",
#        "node_2": "Nous",
#        "edge": "In both Neo-Platonism as well as with Upanishadic philosophy, dharma, the cosmos is brought into existence through this all-pervading cosmic principle reflected in the individual Soul, which corresponds quite neatly to Nous, a sort of Divine Intellect that is rational and reflects a sense of order."
#    },
#    {
#        "node_1": "Soul",
#        "node_2": "Ātman",
#        "edge": "Furthermore, in both Neo-Platonism as well as with Upanishadic philosophy and Christianity as well, the individual manifestation of Brahman through which his creation is experienced, referred to as the Soul, corresponds again quite neatly to Ātman."
#    }
# ][
#    {
#        "node_1": "Indo-European theo-philosophy",
#        "node_2": "Man is created, or exists, in the image of God",
#        "edge": "Implicit in this characteristically Indo-European theo-philosophy is that man is created, or exists, in the image of God - one of the fundamental Indo-European theological tenets implicit in the Upanishads, but also embedded in virtually all of Hellenic philosophy as well which in turn forms the basis of Judeo-Christian theology."
#    },
#    {
#        "node_1": "Indo-European theo-philosophy",
#        "node_2": "Dao",
#        "edge": "In the Chinese tradition, they are somewhat less hamstrung, and came up with the notion of Dao, which is more process (change really) based than it is based upon any sort of subject, or object, or experience. It's a way, a path, an experiential process of 'living', of 'being'."
#    },
#    {
#        "node_1": "Yìjīng",
#        "node_2": "Dao",
#        "edge": "The metaphysics of the Yìjīng supports this as the Dao, as a theo-philosophical principle or tenet, runs almost orthogonal to the Yìjīng when looked at through a metaphysical or philosophical lens."
#    },
#    {
#        "node_1": "Fate",
#        "node_2": "Yìjīng",
#        "edge": "From this perspective, the Yìjīng not only describes Fate itself,"
#    },
#    {
#        "node_1": "Set of possible states of 'being'",
#        "node_2": "Fate",
#        "edge": "but also provides a framework for coaxing out of it potential future outcomes given a) a totality of possible states of 'being'",
#    },
#    {
#        "node_1": "Set of possible states of 'being'",
#        "node_2": "Current state of 'being'",
#        "edge": "and b) knowledge of the relationship of these states to one another, and c) an identification of the current state of 'being' that best describes the current 'situation' as it relates to the total possible set of 'possible existence'."
#    }
# ]
#
#
# ERROR ### Here is the buggy response:  [
#    {
#        "node_1": "Indo-European theo-philosophy",
#        "node_2": "Man is created, or exists, in the image of God",
#        "edge": "Implicit in this characteristically Indo-European theo-philosophy is that man is created, or exists, in the image of God - one of the fundamental Indo-European theological tenets implicit in the Upanishads, but also embedded in virtually all of Hellenic philosophy as well which in turn forms the basis of Judeo-Christian theology."
#    },
#    {
#        "node_1": "Indo-European theo-philosophy",
#        "node_2": "Dao",
#        "edge": "In the Chinese tradition, they are somewhat less hamstrung, and came up with the notion of Dao, which is more process (change really) based than it is based upon any sort of subject, or object, or experience. It's a way, a path, an experiential process of 'living', of 'being'."
#    },
#    {
#        "node_1": "Yìjīng",
#        "node_2": "Dao",
#        "edge": "The metaphysics of the Yìjīng supports this as the Dao, as a theo-philosophical principle or tenet, runs almost orthogonal to the Yìjīng when looked at through a metaphysical or philosophical lens."
#    },
#    {
#        "node_1": "Fate",
#        "node_2": "Yìjīng",
#        "edge": "From this perspective, the Yìjīng not only describes Fate itself,"
#    },
#    {
#        "node_1": "Set of possible states of 'being'",
#        "node_2": "Fate",
#        "edge": "but also provides a framework for coaxing out of it potential future outcomes given a) a totality of possible states of 'being'",
#    },
#    {
#        "node_1": "Set of possible states of 'being'",
#        "node_2": "Current state of 'being'",
#        "edge": "and b) knowledge of the relationship of these states to one another, and c) an identification of the current state of 'being' that best describes the current 'situation' as it relates to the total possible set of 'possible existence'."
#    }
# ]
#
#
#
# [
#    {
#       "node_1": "Chinese theo-philosophical framework",
#       "node_2": "ontological solution",
#       "edge": "The Chinese theo-philosophical framework presents an ontological solution in response to metaphysical and epistemological problems."
#    },
#    {
#       "node_1": "Chinese theo-philosophical framework",
#       "node_2": "means by which one can have dialogue with It",
#       "edge": "The Chinese theo-philosophical framework provides a way for individuals to communicate with the primordial ontological system within which they exist."
#    },
#    {
#       "node_1": "primordial ontological system",
#       "node_2": "individual",
#       "edge": "Individuals are entities that exist within the primordial ontological system."
#    },
#    {
#       "node_1": "Eastern philosophical systems",
#       "node_2": "reductionist ontology",
#       "edge": "The Eastern philosophical systems do not accommodate a reductionist ontology."
#    },
#    {
#       "node_1": "Eastern philosophical systems",
#       "node_2": "vocabulary",
#       "edge": "The vocabulary of Eastern philosophical systems does not support the existence of a reductionist ontology."
#    },
#    {
#       "node_1": "ancient times",
#       "node_2": "establishment of the philosophical tradition",
#       "edge": "The origins of philosophy in ancient times provide us with the best opportunity, in terms of vocabulary and model, to re-integrate that which was lost when we went down the reductionist and materialist path through and via Science."
#    }
# ][
#    {
#        "node_1": "Ancient philosophical systems",
#        "node_2": "Theological aspects",
#        "edge": "Despite their power in integrating the mystical directly into the philosophical framework as if were, ancient philosophical systems are lacking in terms of integrating the last millennia or so of intellectual developments, specifically Science and philosophy advancements since Kant, who effectively integrates empiricist (materialist) and rationalist (idealists) philosophical schools."
#    },
#    {
#        "node_1": "Kant",
#        "node_2": "God",
#        "edge": "In Kant's philosophy, God is an intellectual construct, a necessary condition of his Metaphysics of Morals, but nonetheless not the ontological penultimate principle in any way."
#    },
#    {
#        "node_1": "Ancient philosophical systems",
#        "node_2": "Kant's philosophy",
#        "edge": "Nonetheless are lacking in terms of integrating the last millennia or so of intellectual developments, specifically Science and philosophy advancements since Kant."
#    },
#    {
#        "node_1": "Empiricist (materialist) philosophical schools",
#        "node_2": "Rationalist (idealists) philosophical schools",
#        "edge": "Kant effectively integrates empiricist (materialist) and rationalist (idealists) philosophical schools that had evolved and countered each other since the very dawn of philosophy, civilization really, in the West."
#    },
#    {
#        "node_1": "Copernican revolution",
#        "node_2": "Newtonian Mechanics",
#        "edge": "Ancient philosophical systems are lacking in terms of integrating the last millennia or so of intellectual developments, as reflected specifically for example in the domain of Science, i.e. Physics as it has evolved through the Copernican revolution, Newtonian Mechanics and then most recently with Quantum Mechanics."
#    }
# ][
#    {
#        "node_1": "Kant's epistemology",
#        "node_2": "truth",
#        "edge": "For Kant, Reason is the benchmark of truth, which exists within and is ultimately bound and defined by mankind's ability to perceive or understand."
#    },
#    {
#        "node_1": "Kant's epistemology",
#        "node_2": "mankind's ability to perceive or understand",
#        "edge": "For Kant, his epistemology is fundamentally psychological as it is bound and defined by mankind's ability to perceive or understand."
#    },
#    {
#        "node_1": "Pirsig's Metaphysics of Quality",
#        "node_2": "God",
#        "edge": "In Pirsig's new metaphysical framework, the direct experience of God is presented as a possible firm element of truth from which all truth and knowledge stem."
#    },
#    {
#        "node_1": "Pirsig's Metaphysics of Quality",
#        "node_2": "Quality",
#        "edge": "In Pirsig's new paradigm based on the metaphysical notion of Quality, this concept doesn't truly integrate the mystical experience in a meaningful way."
#    },
#    {
#        "node_1": "Pirsig's Metaphysics of Quality",
#        "node_2": "Value",
#        "edge": "In Pirsig's work, his new paradigm based on the metaphysical notion of Quality hints at a new ontology, but it focuses more on the metaphysics of value rather than integrating the mystical experience in a meaningful way."
#    },
#    {
#        "node_1": "Pirsig's Metaphysics of Quality",
#        "node_2": "Morality",
#        "edge": "From Pirsig's new paradigm based on the metaphysical notion of Quality, a broader and more encompassing system of morality can effectively be inferred."
#    },
#    {
#        "node_1": "Pirsig's Metaphysics of Quality",
#        "node_2": "Western paradigm",
#        "edge": "While Pirsig's new paradigm based on the metaphysical notion of Quality is extraordinarily powerful, it's an altogether Western paradigm from a theological standpoint."
#    }
# ][
#    {
#        "node_1": "Western ideology",
#        "node_2": "Eastern philosophical notion of mysticism",
#        "edge": "The integration of Eastern philosophy with Western Reason requires a new ontological paradigm due to the proliferation of Western ideology taken to the extreme, resulting in societal and political issues."
#    }, {
#        "node_1": "Missing core intellectual paradigm",
#        "node_2": "Problems on grander scale at sociological and political level",
#        "edge": "The absence of a fundamental intellectual structure leads to individual decisions as well as sociopolitical challenges and crises."
#    }, {
#        "node_1": "Quantum Era",
#        "node_2": "Current era of crisis",
#        "edge": "The current era is characterized by persistent challenges and problems, defining the ongoing crisis."
#    }
# ]
# [
#    {
#        "node_1": "ontological problem",
#        "node_2": "higher order of reality",
#        "edge": "required in order to explain the full range of phenomenon"
#    },
#    {
#        "node_1": "ontological problem",
#        "node_2": "epistemological problem",
#        "edge": "in the sense that our current notions of knowledge are wholly inadequate for the job at hand"
#    },
#    {
#        "node_1": "reality",
#        "node_2": "physical phenomenon",
#        "edge": "objective reality"
#    },
#    {
#        "node_1": "reality",
#        "node_2": "experiential reality",
#        "edge": "within which experience itself can take place as a phenomenon in itself"
#    },
#    {
#        "node_1": "world",
#        "node_2": "how we define",
#        "edge": "the inverse which is effectively how 'the world' can be known as well as the inverse which is effectively how we define 'the world'"
#    }
# ][
#    {
#        "node_1": "epistemological paradigm",
#        "node_2": "full range of phenomenon",
#        "edge": "An epistemological paradigm is necessary to encompass the entire spectrum of phenomena, as opposed to just physical or rational realities proposed by philosophers like Aristotle, Bacon, Locke, Plato, Descartes, and Leibniz." },
#    {
#        "node_1": "full range of phenomenon",
#        "node_2": "expansion of notion",
#        "edge": "The concept of phenomena is being expanded to include not only physical or rational realities, but also psychological or experiential ones, as proposed by philosophers like Kant, Freud, and Jung." }
# ][
#    {
#        "node_1": "supra-rational",
#        "node_2": "ontological and metaphysical paradigm",
#        "edge": "enables the establishment of a more global and holistic intellectual paradigm that is applicable beyond just the domain of Philosophy to tackle persistent and global problems in the Quantum Era"
#    },
#    {
#        "node_1": "phenomena",
#        "node_2": "ontological and metaphysical paradigm",
#        "edge": "covers the range of phenomena that are fully integrated as first principles, arche, rather than left outside of it as defining attributes or characteristics"
#    },
#    {
#        "node_1": "Kant",
#        "node_2": "ontological and metaphysical paradigm",
#        "edge": "falls short of what is needed to address persistent and global problems in the Quantum Era, although he laid much of the groundwork for this paradigm"
#    },
#    {
#        "node_1": "consistency",
#        "node_2": "rationality",
#        "edge": "are maintained in order to achieve a more global and holistic intellectual paradigm that can address persistent and global problems in the Quantum Era"
#    },
#    {
#        "node_1": "global challenges",
#        "node_2": "Quantum Era",
#        "edge": "characteristics of our time that require a more global and holistic intellectual paradigm to address"
#    }
# ][
#    {
#        "node_1": "Kant's philosophy",
#        "node_2": "revolutionary",
#        "edge": "Kant's philosophy is characterized as revolutionary due to its ability to integrate the realities of rationalists and empiricists in a single metaphysical system."
#    },
#    {
#        "node_1": "Kant's philosophy",
#        "node_2": "integrates",
#        "edge": "Kant's philosophy integrates the realities of rationalists and empiricists in a single metaphysical system."
#    },
#    {
#        "node_1": "rationalists",
#        "node_2": "realities",
#        "edge": "The realities of rationalists are integrated into Kant's philosophy."
#    },
#    {
#        "node_1": "empiricists",
#        "node_2": "realities",
#        "edge": "The realities of empiricists are integrated into Kant's philosophy."
#    },
#    {
#        "node_1": "Kant's philosophy",
#        "node_2": "declares",
#        "edge": "In Kant's philosophy, knowledge is declared to be how we perceive it through our cognitive faculties and that no other definition of it stands to Reason."
#    },
#    {
#        "node_1": "knowledge",
#        "node_2": "how we perceive it",
#        "edge": "Knowledge is defined as how we perceive it through our cognitive faculties in Kant's philosophy."
#    },
#    {
#        "node_1": "rationalists",
#        "node_2": "definition of knowledge",
#        "edge": "The definition of knowledge as put forward by rationalists is rejected in Kant's philosophy."
#    },
#    {
#        "node_1": "empiricists",
#        "node_2": "definition of knowledge",
#        "edge": "The definition of knowledge as put forward by empiricists is rejected in Kant's philosophy."
#    },
#    {
#        "node_1": "Kant's philosophy",
#        "node_2": "declares",
#        "edge": "In Kant's philosophy, space and time themselves disappear when the subject or even only the subjective constitution of our senses is taken away."
#    },
#    {
#        "node_1": "spatiality",
#        "node_2": "disappears",
#        "edge": "In Kant's philosophy, spatiality disappears when the subject or even only the subjective constitution of our senses is taken away."
#    },
#    {
#        "node_1": "temporality",
#        "node_2": "disappears",
#        "edge": "In Kant's philosophy, temporality disappears when the subject or even only the subjective constitution of our senses is taken away."
#    },
#    {
#        "node_1": "space",
#        "node_2": "nothing in itself",
#        "edge": "According to Kant's philosophy, space itself through which they fall, is nothing in itself but both are mere modifications or fundamental dispositions of our sensible intuition."
#    },
#    {
#        "node_1": "time",
#        "node_2": "nothing in itself",
#        "edge": "According to Kant's philosophy, even time itself through which they fall, is nothing in itself but both are mere modifications or fundamental dispositions of our sensible intuition."
#    },
#    {
#        "node_1": "raindrops",
#        "node_2": "mere appearances",
#        "edge": "In Kant's philosophy, the raindrops themselves are merely appearances."
#    },
#    {
#        "node_1": "circular form",
#        "node_2": "mere modifications",
#        "edge": "According to Kant's philosophy, the circular form of raindrops is a mere modification or fundamental disposition of our sensible intuition."
#    },
#    {
#        "node_1": "transcendental object",
#        "node_2": "unknown to us",
#        "edge": "According to Kant's philosophy, the nature and relations of objects considered as things in themselves and without reference to the receptivity of our sensibility is quite unknown to us."
#    },
#    {
#        "node_1": "Kant's philosophy",
#        "node_2": "Copernican revolution",
#        "edge": "Kant's philosophy represents a Copernican revolution of philosophy in which objective phenomenon and their relations, as well as space and time themselves, are fundamentally psychological phenomena."
#    }
# ][
#    {
#        "node_1": "Reason",
#        "node_2": "man",
#        "edge": "Both Reason and man are considered distinguishing characteristics that separate them from the rest of the species on the planet."
#    },
#    {
#        "node_1": "Reason",
#        "node_2": "divine",
#        "edge": "According to virtually every theo-philosophical tradition, Reason is the means by which man is created in God's image and it is implied in the Eastern theo-philosophical traditions as well."
#    },
#    {
#        "node_1": "Reason",
#        "node_2": "cosmic Reason",
#        "edge": "Reason orders the universe, and it is the cosmic Reason through which the universe is born and sustained in the Neo-Platonic Nous."
#    },
#    {
#        "node_1": "man",
#        "node_2": "divine",
#        "edge": "Both man and the divine are believed to be fundamentally united, as expressed so eloquently in the Judeo-Christian tradition, i.e. the Logos."
#    },
#    {
#        "node_1": "man",
#        "node_2": "spiritual being",
#        "edge": "Man is considered a spiritual being, as a rational being, which gives it the unique disposition and capability to experience the divine directly in Eastern theo-philosophical traditions."
#    },
#    {
#        "node_1": "Kant",
#        "node_2": "Pirsig",
#        "edge": "Both Kant and Pirsig follow similar lines, going back to the beginning as it were, where Reason is considered to be the primordial and most fundamental principle under which all domains of knowledge should be conceived."
#    }
# ]
# [
#    {
#        "node_1": "Enlightenment Era philosophy",
#        "node_2": "Kant's work",
#        "edge": "Kant's work is a specific example of Enlightenment Era philosophy."
#    },
#    {
#        "node_1": "Kant's philosophy",
#        "node_2": "Enlightenment Era philosophy",
#        "edge": "Kant's philosophy is a type of Enlightenment Era philosophy."
#    },
#    {
#        "node_1": "Metaphysics",
#        "node_2": "Kant's work",
#        "edge": "Kant's work, specifically his Critique, represents the very height of Metaphysics during the Enlightenment Era."
#    },
#    {
#        "node_1": "Transcendental idealism",
#        "node_2": "Kant's philosophy",
#        "edge": "Kant's philosophy is characterized by transcendental idealism."
#    },
#    {
#        "node_1": "Coherence",
#        "node_2": "Kant's position",
#        "edge": "Kant's position, specifically his transcendental idealism, is rationally coherent and complete."
#    },
#    {
#        "node_1": "Utilty",
#        "node_2": "Kant's position",
#        "edge": "Kant's position, specifically his transcendental idealism, is fundamentally useful."
#    },
#    {
#        "node_1": "Incompleteness",
#        "node_2": "Said system",
#        "edge": "Given what we know now, said system, in particular Kant's philosophy, is found to be lacking or incomplete."
#    },
#    {
#        "node_1": "Coherence",
#        "node_2": "Said system",
#        "edge": "Previously, the coherence of said system was presumed and accepted."
#    }
# ]
# [
#    {
#        "node_1": "human knowledge",
#        "node_2": "complex topics and problems",
#        "edge": "Moves forward through the expansion of existing knowledge instead of re-invention, as demonstrated by building upon Kant's work in metaphysics and ontology."
#    }, {
#        "node_1": "Internet applications",
#        "node_2": "network stack",
#        "edge": "Inherit and leverage libraries and APIs that encapsulate knowledge about how machines on the Internet exchange traffic, rather than having to understand it themselves."
#    }
# ]
#
# [
#    {
#        "node_1": "Kant's work",
#        "node_2": "human knowledge today",
#        "edge": "Relevant and important with respect to metaphysics and ontology specifically, due to advancements in technology and understanding that were not present during Kant's time."
#    }, {
#        "node_1": "Philosophy",
#        "node_2": "ability to persist and impress upon the minds of each ensuing generation",
#        "edge": "Deters from its ability to do so due to a tendency to re-invent everything every generation."
#    }
# ]
#
# ERROR ### Here is the buggy response:  [
#    {
#        "node_1": "human knowledge",
#        "node_2": "complex topics and problems",
#        "edge": "Moves forward through the expansion of existing knowledge instead of re-invention, as demonstrated by building upon Kant's work in metaphysics and ontology."
#    }, {
#        "node_1": "Internet applications",
#        "node_2": "network stack",
#        "edge": "Inherit and leverage libraries and APIs that encapsulate knowledge about how machines on the Internet exchange traffic, rather than having to understand it themselves."
#    }
# ]
#
# [
#    {
#        "node_1": "Kant's work",
#        "node_2": "human knowledge today",
#        "edge": "Relevant and important with respect to metaphysics and ontology specifically, due to advancements in technology and understanding that were not present during Kant's time."
#    }, {
#        "node_1": "Philosophy",
#        "node_2": "ability to persist and impress upon the minds of each ensuing generation",
#        "edge": "Deters from its ability to do so due to a tendency to re-invent everything every generation."
#    }
# ]
#
#
# [
#    {
#        "node_1": "human mind",
#        "node_2": "Kant's metaphysics",
#        "edge": "starting point for taking ontological first principle"
#    },
#    {
#        "node_1": "human mind",
#        "node_2": "cognitive engine",
#        "edge": "equated by Kant through which all knowledge gained"
#    },
#    {
#        "node_1": "a priori knowledge",
#        "node_2": "human mind",
#        "edge": "unique type of knowledge that is gained by this cognitive entity"
#    },
#    {
#        "node_1": "time and space",
#        "node_2": "a priori knowledge",
#        "edge": "represent not basic objective or rational phenomena but phenomena that exist as a function of the mind and its cognitive capabilities"
#    },
#    {
# ...
#        "edge": "Mankind's relationship with truth was symbolic in antiquity, as was their approach to conveying truth allegorically (allegoresis)."
#    },
#    {
#        "node_1": "mythos",
#        "node_2": "allegoresis",
#        "edge": "In antiquity, mankind's approach to conveying the underlying truth of mythos was allegorical (allegoresis)."
#    },
#    {
#        "node_1": "antiquity",
#        "node_2": "mythos",
#        "edge": "Mankind in antiquity believed in the underlying truth of mythos."
#    },
#    {
#        "node_1": "antiquity",
#        "node_2": "allegoresis",
#        "edge": "In antiquity, mankind's approach to conveying the underlying truth of mythos was allegorical."
#    },
#    {
#        "node_1": "truth",
#        "node_2": "mythos",
#        "edge": "The belief in the underlying truth of mythos persisted even as mankind's relationship with truth evolved from symbolic to linguistic specificity."
#    },
#    {
#        "node_1": "linguistic specificity",
#        "node_2": "truth",
#        "edge": "As mankind's relationship with truth evolved from symbolic to linguistic specificity, the loss of the mystery of creation occurred as a result."
#    },
#    {
#        "node_1": "symbolism",
#        "node_2": "linguistic specificity",
#        "edge": "The evolution of mankind's relationship with truth from symbolic to linguistic specificity led to the loss of the mystery of creation."
#    },
#    {
#        "node_1": "reason",
#        "node_2": "truth",
#        "edge": "Reason was looked upon as the benchmark of knowledge and truth in mankind's intellectual journey from symbolism to linguistic specificity."
#    },
#    {
#        "node_1": "mysticism",
#        "node_2": "creation",
#        "edge": "Mystical progression of words to thoughts to ideas led to the grounds for religion and philosophy, ultimately merging with the source of creation itself in Hellenic antiquity."
#    },
#    {
#        "node_1": "creation",
#        "node_2": "mysticism",
#        "edge": "The mystical progression of words to thoughts to ideas led to the grounds for religion and philosophy, ultimately merging with the source of creation itself."
#    },
#    {
#        "node_1": "wisdom",
#        "node_2": "sophia",
#        "edge": "The exercise of reflection on truth (philosophia) was considered to be not just rational, but a reflection of cosmic wisdom (sophia), which ultimately merged with the source of creation itself."
#    },
#    {
#        "node_1": "cosmic",
#        "node_2": "wisdom",
#        "edge": "The exercise of reflection on truth (philosophia) was considered to be not just rational, but a reflection of cosmic wisdom."
#    }
# ][
#    {
#        "node_1": "Awareness",
#        "node_2": "Being",
#        "edge": "In Hellenic antiquity, the notion of Awareness was referred to primarily as Being. From an ontological perspective, both ideas and objective reality are seen as real or true."
#    }, {
#        "node_1": "Awareness",
#        "node_2": "Thought",
#        "edge": "In the Platonic tradition, Awareness was considered to be the very ground of thought."
#    }, {
#        "node_1": "Being",
#        "node_2": "Existence",
#        "edge": "From an ontological perspective, Being is understood as the ground of existence."
#    }, {
#        "node_1": "Ideas",
#        "node_2": "Awareness",
#        "edge": "In the Platonic tradition, ideas are understood as higher order constructs that reflect universal order and rest in the ground of Awareness."
#    }, {
#        "node_1": "Things",
#        "node_2": "Being",
#        "edge": "Things - objects or physical reality - reflect a lower order construct, ontologically speaking, than ideas, which again rest in the ground of Being."
#    }, {
#        "node_1": "Logos",
#        "node_2": "Nous",
#        "edge": "The Neo-Platonists had right the notion of Nous and Logos. Both representing that primordial ordering force which underpinned, and was the source of, universal creation."
#    }, {
#        "node_1": "Divine Intellect",
#        "node_2": "Nous",
#        "edge": "Each representing that primordial ordering force which underpinned, and was the source of, universal creation, and at the same time permeates it and binds it together."
#    }
# ][
#    {
#        "node_1": "written word",
#        "node_2": "intellectual construct",
#        "edge": "The written word represents a fundamentally reductionist and objective realist metaphysical implication, while that which truly binds the universe is not an intellectual construct but rather 'spiritual' due to its fundamentally divine sense of order that reflects a fundamentally alive universe."
#    },
#    {
#        "node_1": "written word",
#        "node_2": "expressive and intellectual power",
#        "edge": "The written word, as a significant technological innovation of ancient man, provides the intellectual architecture and building blocks for philosophy in antiquity that forms the basis of Philosophy and Science in the post Enlightenment Era. It nonetheless limits our understanding to a large degree of the bigger picture due to its metaphysical implications."
#    },
#    {
#        "node_1": "divine",
#        "node_2": "breath or spirit",
#        "edge": "The notion of divine aligns directly with breath, or spirit - Holy Spirit, pneuma, prāṇa, etc. - as a fundamentally primordial first principle in the Metaphysics of Awareness that goes back to the early Indo-Europeans."
#    },
#    {
#        "node_1": "universe",
#        "node_2": "aware",
#        "edge": "The totality of being, the universe, is fundamentally alive, i.e. is 'aware'."
#    }
# ]
# [
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "Holistic conception of universal world order",
#        "edge": "The Metaphysics of Awareness reflects a more holistic conception of the universal world order."
#    },
#    {
#        "node_1": "Eastern and Western philosophy",
#        "node_2": "Complimentary intellectual domains",
#        "edge": "The Eastern and Western vantage points serve as complimentary intellectual domains, two parts and perspectives on the entire domain of knowledge for the entire human experience - the Yīn-Yáng of the entire expanse of human knowledge as it were rather than mutually exclusive domains of truth."
#    },
#    {
#        "node_1": "Holistic versus reductionist ontologies",
#        "node_2": "Different perspectives on the world order",
#        "edge": "If we look at Religion and Science not as separate domains of knowledge (with never the two shall meet so to speak) but if we see them as different perspectives on the world order through this lens of holistic versus reductionist ontologies,"
#    },
#    {
#        "node_1": "Theology",
#        "node_2": "Philosophia which subsumed",
#        "edge": "The Metaphysics of Awareness then, is a sort of metaphysical synthetic that leverages some of the very fundamental principles that rest at the heart of ancient philosophy, i.e. philosophia which subsumed theology,"
#    },
#    {
#        "node_1": "Ontology",
#        "node_2": "Emerged as intellectual constructs",
#        "edge": "The Metaphysics of Awareness reflects a more holistic conception of the universal world order, a worldview that was predominant well before ontology, epistemology, theology or metaphysics even existed as intellectual constructs much less specific domains of knowledge in and of themselves,"
#    },
#    {
#        "node_1": "Reductionist worldview",
#        "node_2": "Baked into the language itself",
#        "edge": "The now more predominant, Western, reductionist worldview - baked into the language itself - had yet to take over the intellectual landscape."
#    },
# ]
#
# ERROR ### Here is the buggy response:  [
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "Holistic conception of universal world order",
#        "edge": "The Metaphysics of Awareness reflects a more holistic conception of the universal world order."
#    },
#    {
#        "node_1": "Eastern and Western philosophy",
#        "node_2": "Complimentary intellectual domains",
#        "edge": "The Eastern and Western vantage points serve as complimentary intellectual domains, two parts and perspectives on the entire domain of knowledge for the entire human experience - the Yīn-Yáng of the entire expanse of human knowledge as it were rather than mutually exclusive domains of truth."
#    },
#    {
#        "node_1": "Holistic versus reductionist ontologies",
#        "node_2": "Different perspectives on the world order",
#        "edge": "If we look at Religion and Science not as separate domains of knowledge (with never the two shall meet so to speak) but if we see them as different perspectives on the world order through this lens of holistic versus reductionist ontologies,"
#    },
#    {
#        "node_1": "Theology",
#        "node_2": "Philosophia which subsumed",
#        "edge": "The Metaphysics of Awareness then, is a sort of metaphysical synthetic that leverages some of the very fundamental principles that rest at the heart of ancient philosophy, i.e. philosophia which subsumed theology,"
#    },
#    {
#        "node_1": "Ontology",
#        "node_2": "Emerged as intellectual constructs",
#        "edge": "The Metaphysics of Awareness reflects a more holistic conception of the universal world order, a worldview that was predominant well before ontology, epistemology, theology or metaphysics even existed as intellectual constructs much less specific domains of knowledge in and of themselves,"
#    },
#    {
#        "node_1": "Reductionist worldview",
#        "node_2": "Baked into the language itself",
#        "edge": "The now more predominant, Western, reductionist worldview - baked into the language itself - had yet to take over the intellectual landscape."
#    },
# ]
#
#
# [
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "unity and emanation",
#        "edge": "The Metaphysics of Awareness implies a reality that reflects first order principles of unity and emanation."
#    },
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "ancient philosophy",
#        "edge": "The Metaphysics of Awareness can be traced back to the beginning as it were, and is a fundamental principle in virtually all forms of ancient philosophy."
#    },
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "Ontological Interpretation of Quantum Mechanics",
#        "edge": "The Ontological Interpretation of Quantum Mechanics is closely related to the Metaphysics of Awareness."
#    },
#    {
#        "node_1": "Ontological Interpretation of Quantum Mechanics",
#        "node_2": "David Bohm",
#        "edge": "The Ontological Interpretation of Quantum Mechanics was established by David Bohm, a prominent physicist."
#    },
#    {
#        "node_1": "Ontological Interpretation of Quantum Mechanics",
#        "node_2": "de Broglie-Bohm theory",
#        "edge": "The Ontological Interpretation of Quantum Mechanics is also known as de Broglie-Bohm theory."
#    },
#    {
#        "node_1": "Ontological Interpretation of Quantum Mechanics",
#        "node_2": "Eastern philosophy and mysticism",
#        "edge": "The proliferation of Eastern philosophy and mysticism in the 21st century has led to a renewed consideration of this interpretation."
#    },
#    {
#        "node_1": "quantum potential",
#        "node_2": "Ontological Interpretation of Quantum Mechanics",
#        "edge": "The Ontological Interpretation of Quantum Mechanics introduces the notion of quantum potential to its mathematical foundations."
#    },
#    {
#        "node_1": "localization",
#        "node_2": "Classical Mechanics",
#        "edge": "Localization is a fundamental principle of Classical Mechanics that is relaxed in this interpretation of Quantum Mechanics."
#    }
# ][
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "Quantum Mechanics",
#        "edge": "Bohmian Mechanics integrates the notion of Awareness into the heart of Quantum Mechanics as its metaphysical and ontological ground for his conception of undivided wholeness."
#    },
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "Undivided Wholeness",
#        "edge": "Bohm's Metaphysics of Awareness provides a philosophical rendition of his conception of undivided wholeness."
#    },
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "Integration",
#        "edge": "The Metaphysics of Awareness integrates the dualism of Kant and non-dualism of Śaṅkara into a single metaphysical and epistemological paradigm."
#    },
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "Existence",
#        "edge": "The Metaphysics of Awareness establishes Awareness as an ontological first principle, a psychological and philosophical imperative that provides the foundation for all existence."
#    },
#    {
#        "node_1": "Metaphysics of Awareness",
#        "node_2": "Knowledge",
#        "edge": "The Metaphysics of Awareness provides the rational foundations for all knowledge."
#    },
#    {
#        "node_1": "Quantum Mechanics",
#        "node_2": "Bohmian Mechanics",
#        "edge": "Bohm himself argues, to a certain degree, that Bohmian Mechanics adds the notion of Awareness into the very heart of Quantum Mechanics."
#    },
#    {
#        "node_1": "Quantum Era",
#        "node_2": "Quantum Mechanics",
#        "edge": "The Quantum Era is now officially behind us, and we must usher in a new Era - the Quantum Era."
#    },
#    {
#        "node_1": "Philosophy",
#        "node_2": "New Era",
#        "edge": "Let it be ushered in properly not by Physics, Psychology or Religion - but by Philosophy, like every Era should be."
#    }
# ][
#    {
#        "node_1": "Awareness",
#        "node_2": "existence",
#        "edge": "In this context, 'Awareness' is being presented as the metaphysical ground of existence itself. This implies that Awareness and existence are intimately related, possibly synonymous or interdependent concepts. It suggests that by establishing the verity of Awareness, we may also be verifying the existence itself."
#    },
#    {
#        "node_1": "Awareness",
#        "node_2": "epistemological framework",
#        "edge": "The text states that 'Awareness' can serve as a new epistemological framework. This implies that Awareness has the potential to provide us with a new way of understanding and organizing knowledge, which is different from traditional epistemological frameworks."
#    },
#    {
#        "node_1": "Philosophy",
#        "node_2": "epistemological framework",
#        "edge": "The text mentions that the new epistemological framework is grounded not just in Philosophy, but also in Physics through mathematics. This implies that Philosophy and epistemological frameworks can be closely related, and that this relationship may involve other disciplines as well."
#    },
#    {
#        "node_1": "Physics",
#        "node_2": "epistemological framework",
#        "edge": "The text highlights the involvement of Physics in grounding the new epistemological framework. This implies that Physics and epistemological frameworks can also be related, possibly through mathematics or other shared concepts."
#    }
# ](319, 7)
#                          node_1                  node_2  \
# 0           rise of nationalism                  brexit
# 1           rise of nationalism                trumpism
# 2           rise of nationalism                populism
# 3  increasing wealth inequality          general unrest
# 4  increasing wealth inequality  broad class inequality
#
#                                                 edge  \
# 0  Brexit is an example of the rise of nationalis...
# 1  Trumpism refers to the nationalistic ideology ...
# 2  Nationalism is a form of populism that emphasi...
# 3  Wealth inequality has been linked to social un...
# 4  Wealth inequality is a major contributor to cl...
#
#                            chunk_id node_3 node_4  count
# 0  d53bb76260354f97b2371261f9d56b0f    NaN    NaN      4
# 1  d53bb76260354f97b2371261f9d56b0f    NaN    NaN      4
# 2  d53bb76260354f97b2371261f9d56b0f    NaN    NaN      4
# 3  d53bb76260354f97b2371261f9d56b0f    NaN    NaN      4
# 4  d53bb76260354f97b2371261f9d56b0f    NaN    NaN      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#             node_1                             node_2  \
# 3805  written word  expressive and intellectual power
# 3806  written word             intellectual construct
# 3807  written word                           universe
# 3822         ātman                               nous
# 3839           ṛta                               nous
#
#                                                chunk_id  count  \
# 3805  f62f8db6563747aaa0e938921f5e0018,f62f8db656374...      2
# 3806  f62f8db6563747aaa0e938921f5e0018,f62f8db656374...      2
# 3807  f62f8db6563747aaa0e938921f5e0018,f62f8db656374...      2
# 3822  11d53ee631b148c4ba2dfe7412820c02,11d53ee631b14...      2
# 3839  11d53ee631b148c4ba2dfe7412820c02,11d53ee631b14...      2
#
#                       edge
# 3805  contextual proximity
# 3806  contextual proximity
# 3807  contextual proximity
# 3822  contextual proximity
# 3839  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                   node_1                  node_2  \
# 0               a priori             assumptions
# 1               a priori              experience
# 2     a priori knowledge        cognitive engine
# 3     a priori knowledge                 context
# 4     a priori knowledge        human experience
# ...                  ...                     ...
# 1547        written word  intellectual construct
# 1548        written word                universe
# 1549                  yi      chinese philosophy
# 1550               ātman                    nous
# 1551                 ṛta                    nous
#
#                                                chunk_id  \
# 0                      fb124986290242fca98717f4866cc82a
# 1     fb124986290242fca98717f4866cc82a,fb12498629024...
# 2     e27516625d5a428e9684ee6801adec8a,e27516625d5a4...
# 3     e27516625d5a428e9684ee6801adec8a,e27516625d5a4...
# 4     e27516625d5a428e9684ee6801adec8a,e27516625d5a4...
# ...                                                 ...
# 1547  f62f8db6563747aaa0e938921f5e0018,f62f8db656374...
# 1548  f62f8db6563747aaa0e938921f5e0018,f62f8db656374...
# 1549                   3c1d825c76c744f4958f5eee6ec5dfd8
# 1550  11d53ee631b148c4ba2dfe7412820c02,11d53ee631b14...
# 1551  11d53ee631b148c4ba2dfe7412820c02,11d53ee631b14...
#
#                                                    edge  count
# 0     Kant pushed the predominant worldview into his...      4
# 1                                  contextual proximity      2
# 2                                  contextual proximity      2
# 3                                  contextual proximity      2
# 4                                  contextual proximity      2
# ...                                                 ...    ...
# 1547  The written word represents a fundamentally re...      6
# 1548                               contextual proximity      2
# 1549  The yi, which is reflective of ancient Chinese...      4
# 1550                               contextual proximity      2
# 1551                               contextual proximity      2
#
# [1552 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (342,)

# %%
#pip install networks networkx

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  33
# [['a priori', 'all beings, all existence', 'allegoresis', 'ancient philosophical systems', 'ancient philosophy', 'ancient theology', 'antiquity', 'aristotle', 'assumptions', 'aware', 'awareness', 'being', 'being and cognition', 'bohmian mechanics', 'brahman', 'brahmā', 'breath or spirit', 'change', 'classical concept', 'classical mechanics', 'cognition', 'cognitive experience', 'cognitive faculties', 'cognitive framework', 'cognitive process', 'comprehension', 'comprehension or understanding', 'conception of reality', 'consciousness', 'consistency', 'cosmic', 'cosmic reason', 'creation', 'current era of crisis', 'david bohm', 'de broglie-bohm theory', 'defining feature', 'definitive boundaries of knowledge', 'desire', 'dharma', 'direct experience of the ground of existence or ground of being, which is equivalent to god.', 'divine', 'divine being', 'divine intellect', 'divine intellect and the soul', 'dynamic quality', 'eastern and western philosophy', 'eastern philosophical and mystical implications', 'eastern philosophy', 'eastern philosophy and mysticism', 'einstein', 'empiricist (materialist) philosophical schools', 'empricial realist position', 'epistemological entity', 'epistemological framework', 'epistemological problem', 'epistemology', 'eros', 'existence', 'existence-knowledge-bliss-absolute', 'experience', 'experiential reality', 'expressive and intellectual power', 'freudian psychology', 'global aggregate construct', 'global challenges', 'god', 'ground of being', 'ground of experience', 'happiness', 'higher order knowledge', 'higher order level or dimension or reality or existence', 'higher order of reality', 'how we define', 'ideas', 'indian philosophical conception of knowledge', 'indian philosophy', 'individual and collective level', 'individual consciousness or cognition', 'individual psyche', 'individualization', "individualized and discrete 'thing'", 'individuation', 'integration', 'intellectual and metaphysical constructs', 'intellectual as well as physical and spiritual ground of experience', 'intellectual construct', 'intellectual perspective', 'interconnectedness principle', 'islam', 'journey back up metaphysical paradigm', "jung's collective unconscious", "jung's concept of individuation", 'jungian archetypes', 'jungian psychology', 'kant', "kant's epistemological framework", "kant's epistemology", "kant's metaphysics", 'kosmos', 'lacks metaphysical structure', 'life', 'linguistic specificity', 'locality', 'localization', 'logos', 'lower forms of knowledge', 'lower forms of knowledge and existence', 'man', "mankind's ability to perceive or understand", 'many', 'many worlds interpretation', 'metaphysical construct', 'metaphysical entity', 'metaphysical grounding of the experience', 'metaphysical or ontological principle', 'metaphysical perspective', 'metaphysical principle', 'metaphysician', 'metaphysics of awareness', 'metaphysics of mind', 'morality', 'morality and ethics', 'mysticism', 'mythos', 'nature of experience', 'neo-platonic one', 'neo-platonism', 'neo-platonist', 'new era', 'nirvana', 'nous', 'objective', 'objective realism', 'objective realism or even quantum mechanics', 'objectively and empirically based and physical sciences', 'one', 'ontological and metaphysical paradigm', 'ontological entity', 'ontological interpretation of quantum mechanics', 'ontological problem', 'ontologically prior', 'ontology', 'overlooked spatial, time and embodiment constraints', 'perception', 'phenomena', 'philosophia', 'philosophy', 'philosophy and psychology', 'physical phenomenon', 'physical world', 'physics', 'pirsig', "pirsig's metaphysics of quality", 'planet', 'plato', 'platonic forms', 'plotinus', 'practical philosophy', 'predominant ontological perspective', 'process', 'psychological perspective', 'quality', 'quantum era', 'quantum mechanics', 'quantum potential', 'quantum revolution', 'quantum theory', 'rationalist (idealists) philosophical schools', 'rationality', 'real thing', 'reality', 'reason', 'rea ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                             node    color  group
# 0                                       a priori  #db7757      1
# 1                      all beings, all existence  #db7757      1
# 2                                    allegoresis  #db7757      1
# 3                  ancient philosophical systems  #db7757      1
# 4                             ancient philosophy  #db7757      1
# ..                                           ...      ...    ...
# 337  successfully through the crisis of our time  #57db5f     31
# 338                                      quantum  #afdb57     32
# 339                                        slits  #afdb57     32
# 340                          supracconsciousness  #d757db     33
# 341               underlying ground of existence  #d757db     33
#
# [342 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
#pip install pyvis

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
